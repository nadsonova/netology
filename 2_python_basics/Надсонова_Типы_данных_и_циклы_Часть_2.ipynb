# %%
# Задание 1

ids = {'user1': [213, 213, 213, 15, 213], 
       'user2': [54, 54, 119, 119, 119], 
       'user3': [213, 98, 98, 35]}

set(sum([geo for geo in ids.values()], []))
# Out:
# {15, 35, 54, 98, 119, 213}

# %%
# Задание 2

queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт',
    'летом',
    'курс ',
    'сериалы про спорт спорт спорт',
    ' сериалы'
]

word_count = {}
for querie in queries:
  word_count.setdefault(len(querie.split()), 0)
  word_count[len(querie.split())] += 1

for word, count in word_count.items():
  print(f'Поисковых запросов, содержащих {word} слов(а): {round(100 * count / len(queries), 2)}%')
# Out:
# Поисковых запросов, содержащих 3 слов(а): 36.36%
# Поисковых запросов, содержащих 2 слов(а): 27.27%
# Поисковых запросов, содержащих 1 слов(а): 27.27%
# Поисковых запросов, содержащих 5 слов(а): 9.09%

# %%
# Задание 3

results = {
    'vk': {'revenue': 103, 'cost': 98},
    'yandex': {'revenue': 179, 'cost': 153},
    'facebook': {'revenue': 103, 'cost': 110},
    'adwords': {'revenue': 35, 'cost': 34},
    'twitter': {'revenue': 11, 'cost': 24},
}

for name, data in results.items():
  data['ROI'] = round((data['revenue'] / data['cost'] - 1) * 100, 2)

results
# Out:
# {'vk': {'revenue': 103, 'cost': 98, 'ROI': 5.1},
#  'yandex': {'revenue': 179, 'cost': 153, 'ROI': 16.99},
#  'facebook': {'revenue': 103, 'cost': 110, 'ROI': -6.36},
#  'adwords': {'revenue': 35, 'cost': 34, 'ROI': 2.94},
#  'twitter': {'revenue': 11, 'cost': 24, 'ROI': -54.17}}

# %%
# Задание 4

stats = {'facebook': 55, 'yandex': 115, 'vk': 120, 'google': 99, 'email': 42, 'ok': 98}

print(f'Максимальный объем продаж на рекламном канале: {sorted(stats.items(), key=lambda x: x[1])[-1][0]}')
# Out:
# Максимальный объем продаж на рекламном канале: vk

# %%
# Задание 5

my_list = ['2018-01-01', 'yandex', 'cpc', 100]
#my_list = ['a', 'b', 'c', 'd', 'e', 'f']

new_list = {my_list[-2]: my_list[-1]}
my_list.reverse()

for i in range(len(my_list) - 2):
    new_list = {my_list[i+2]: new_list}

print(new_list)
# Out:
# {'2018-01-01': {'yandex': {'cpc': 100}}}

# %%
# Задание 6

cook_book = {
  'салат': [
     {'ingridient_name': 'сыр', 'quantity': 50, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 2, 'measure': 'шт'},
     {'ingridient_name': 'огурцы', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'маслины', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'оливковое масло', 'quantity': 20, 'measure': 'мл'},
     {'ingridient_name': 'салат', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'перец', 'quantity': 20, 'measure': 'гр'}
    ],
  'пицца': [
     {'ingridient_name': 'сыр', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'колбаса', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'бекон', 'quantity': 30, 'measure': 'гр'},
     {'ingridient_name': 'оливки', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'томаты', 'quantity': 20, 'measure': 'гр'},
     {'ingridient_name': 'тесто', 'quantity': 100, 'measure': 'гр'},   
    ],
  'лимонад': [
     {'ingridient_name': 'лимон', 'quantity': 1, 'measure': 'шт'},
     {'ingridient_name': 'вода', 'quantity': 200, 'measure': 'мл'},
     {'ingridient_name': 'сахар', 'quantity': 10, 'measure': 'гр'},
     {'ingridient_name': 'лайм', 'quantity': 20, 'measure': 'гр'},    
    ],
  'пирог': [
     {'ingridient_name': 'тесто', 'quantity': 300, 'measure': 'гр'},
     {'ingridient_name': 'лимон', 'quantity': 5, 'measure': 'шт'},
     {'ingridient_name': 'сахар', 'quantity': 150, 'measure': 'гр'},
     {'ingridient_name': 'лайм', 'quantity': 1, 'measure': 'шт'},    
    ]
}

full_recept = {}
portions = int(input('Введите количество порций: '))

for recept in cook_book.values():
  for ing in recept:
    ing_name, ing_quantity, ing_measure = ing.values()
    item = f'{ing_name} - {ing_measure}'
    
    if item not in full_recept:
      full_recept[item] = {'name': ing_name, 'quantity': ing_quantity * portions, 'measure': ing_measure}
    else:
      full_recept[item].update(quantity = full_recept[item]['quantity'] + ing_quantity * portions)

print(*[f"{ing['name'].capitalize()}: {ing['quantity']} {ing['measure']}" for ing in full_recept.values()], sep='\n')
# Out:
# Введите количество порций: 2
# Сыр: 140 гр
# Томаты: 4 шт
# Огурцы: 40 гр
# Маслины: 20 гр
# Оливковое масло: 40 мл
# Салат: 20 гр
# Перец: 40 гр
# Колбаса: 60 гр
# Бекон: 60 гр
# Оливки: 20 гр
# Томаты: 40 гр
# Тесто: 800 гр
# Лимон: 12 шт
# Вода: 400 мл
# Сахар: 320 гр
# Лайм: 40 гр
# Лайм: 2 шт
