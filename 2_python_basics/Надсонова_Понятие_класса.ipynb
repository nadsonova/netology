# %%
# Задание 1

import requests

class MaxRate:
  def exchange_rates(self):
    """
    Возвращает ответ сервиса с информацией о валютах
    """
    self.request =  requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
    return self.request.json()['Valute']
  
  def max_rate(self):
    """
    Возвращает наименование валюты с максимальным значением курса
    """
    response = self.exchange_rates()
    rates = {response[r]['Value']: response[r]['Name'] for r in response} 
    return rates[sorted(rates)[-1]]

rate = MaxRate()
rate.max_rate()
# Out:
# 'СДР (специальные права заимствования)'

# %%
# Задание 2

class Rate:
    def __init__(self, format_='value', diff_=True):
        self.format = format_
        self.diff = diff_
    
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        self.r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return self.r.json()['Valute']
    
    def make_format(self, currency):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
              if self.diff:
                return round(abs(float(response[currency]['Value']) - float(response[currency]['Previous'])), 4)
              else:
                return response[currency]['Value']
        
        return 'Error'
    
    def eur(self):
        """Возвращает курс евро на сегодня в формате self.format"""
        return self.make_format('EUR')
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        return self.make_format('USD')
    
    def brl(self):
        """Возвращает курс бразильского реала на сегодня в формате self.format"""
        return self.make_format('BRL')

# %%
r = Rate()
r.brl()
# Out:
# 0.1206

# %%
r = Rate(diff_ = False)
r.brl()
# Out:
# 15.8893

# %%
# Задание 3

class Employee:
  def __init__(self, name, seniority):
    self.name = name
    self.seniority = seniority
    self.grade = 1

  def grade_up(self):
    self.grade += 1
    
  def publish_grade(self):
    print(self.name, self.grade)

class Designer(Employee):
  def __init__(self, name, seniority, award = 2):
    self.award = award
    super().__init__(name, seniority + 2 * award)

  def get_international_award(self):
    self.award += 1
    self.seniority += 2

    while int(self.seniority / 7) >= 1:
      self.seniority -= 7
      self.grade_up()

    return self.publish_grade()

# %%
game_designer = Designer(name = 'Marta', seniority = 1)
animator = Designer(name = 'Fill', seniority = 0)
web_designer = Designer(name = 'Chandler', seniority = 1, award = 10)
product_designe = Designer(name = 'Monica', seniority = 5)

# %%
for i in range(10):
  game_designer.get_international_award()
# Out:
# Marta 2
# Marta 2
# Marta 2
# Marta 2
# Marta 3
# Marta 3
# Marta 3
# Marta 4
# Marta 4
# Marta 4

# %%
for i in range(10):
  animator.get_international_award()
# Out:
# Fill 1
# Fill 2
# Fill 2
# Fill 2
# Fill 3
# Fill 3
# Fill 3
# Fill 3
# Fill 4
# Fill 4

# %%
for i in range(10):
  product_designe.get_international_award()
# Out:
# Monica 2
# Monica 2
# Monica 3
# Monica 3
# Monica 3
# Monica 4
# Monica 4
# Monica 4
# Monica 4
# Monica 5

# %%
for i in range(10):
  web_designer.get_international_award()
# Out:
# Chandler 4
# Chandler 4
# Chandler 4
# Chandler 5
# Chandler 5
# Chandler 5
# Chandler 6
# Chandler 6
# Chandler 6
# Chandler 6
